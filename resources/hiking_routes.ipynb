# %% [markdown]
# /* sample Table Mountain query: */
#
# [out:json];
# (
#   way["highway"~"path|footway"](around:9000,-33.95906351,18.4038716);  // Adjust radius and coordinates
#   relation["route"="hiking"](around:9000,-33.95906351,18.4038716);
# );
# out geom;

# %% [markdown]
# // Simon's Town - Cape Town train
# [out:json];
# (
#     relation(id:9822440);
# );
# out geom;

# %% [markdown]
# /* Table Mountain query: */
#
# [out:json];
# (
#   relation(id:14144595); // Lion's Head
#   way(id:71298816);
#   way(id:6169716); // Signal Hill
#   way(id:71296713);
#   way(id:71296708); // Signal Hill
#   way(id:6170196); // Signal Hill
#   way(id:1060647361); // Signal Hill
#   way(id:71296696); // Signal Hill
#   way(id:658371482); // Signal Hill
#   way(id:500902235); // Signal Hill
#   way(id:1060568438); // Signal Hill
#   way(id:549589634); // Signal Hill
#   way(id:71296701); // Signal Hill
#   way(id:1060568435); // Signal Hill
#   way(id:1060568436); // Signal Hill
#   relation(id:6693845); // India Venster
#   way(id:1220582245); // Pipe Track
#   way(id:479583039); // Pipe Track
#   way(id:481822637); // Pipe Track
#   way(id:481822640); // Pipe Track
#   way(id:479583038);
#   way(id:9641373);
#   way(id:24535511);
#   relation(id:7057855); // Kasteelspoort
#   way(id:1346147496);
#   way(id:37229330); // Twelve Apostles
#   way(id:426104528); // Twelve Apostles
#   way(id:426104524); // Twelve Apostles
#   way(id:39499870); // Twelve Apostles
#   way(id:28437132); // Twelve Apostles
#   way(id:468750122);
#   way(id:1061802014);
#   way(id:1050580091);
#   way(id:1050580092);
#   way(id:613420107);
#   way(id:221908339); // Platteklip Gorge
#   way(id:479583040); // Platteklip
#   way(id:221908338); // Platteklip
#   way(id:23750040); // Platteklip
#   way(id:27609018);
#   way(id:927153477);
#   way(id:927153471);
#   way(id:926886151);
#   way(id:927153476);
#   way(id:27609015);
#   way(id:1061798265);
#   way(id:926719823);
#   way(id:1061798267);
#   way(id:1061798266);
#   way(id:1061798268);
#   way(id:926880859);
#   way(id:927256599);
#   way(id:927256600);
#   way(id:926719888);
#   way(id:926719831);
#   way(id:927153454);
#   way(id:926719830);
#   way(id:926719828);
#   way(id:926719829);
#   way(id:927153452);
#   way(id:927153493);
#   way(id:927153491);
#   way(id:45278029);
#   way(id:1061798269);
#   way(id:926719833);
#   way(id:927153485);
#   way(id:926719832);
#   way(id:927153486);
#   way(id:927153489);
#   way(id:926719825);
#   way(id:926719826);
#   way(id:158010356);
#   way(id:926880825);
#   way(id:926880864);
#   way(id:926880865);
#   way(id:926719874);
#   way(id:926719861);
#   way(id:204968408);
#   way(id:926719819);
#   way(id:926719865);
#   way(id:926880872);
#   way(id:926721280);
#   way(id:926880868);
#   way(id:926880870);
#   way(id:926719882);
#   way(id:926719843);
#   way(id:682379967);
#   way(id:926719868);
#   way(id:682379965);
#   way(id:349638366);
#   way(id:349638365);
#   way(id:926719860);
#   way(id:926719862);
#   way(id:926880834);
#   way(id:927153490);
#   way(id:927153492);
#   way(id:927153453);
#   way(id:927153451);
#   way(id:927153488);
#   way(id:927153487);
#   way(id:927153484);
#   way(id:927153475);
#   way(id:451603854);
#   way(id:926880834);
#   way(id:926880869);
#   way(id:926880867);
#   way(id:1061798270);
#   way(id:927153433);
#   way(id:453264254); // Table
#   way(id:23750269); // Table
#   way(id:349638368); // Table
#   way(id:682379966); // Table
#   way(id:27609016); // Table
#   way(id:926719824); // Table
#   way(id:926719827); // Table
#   way(id:27609017); // Table
#   way(id:926719863); // Table
#   way(id:926880826); // Table
#   way(id:926880871); // Table
#   way(id:349638364); // Table
#   way(id:26218387); // Table
#   way(id:926880858); // Table
#   way(id:926719889); // Table
#   way(id:26218389);
#   way(id:451603856);
#   way(id:453264256);
#   way(id:453264257);
#   way(id:291329402); // Maclear's Beacon
#   way(id:1001152188);
#   way(id:479583042);
#   way(id:452279906);
#   way(id:1248799190);
#   way(id:1061802016);
#   way(id:479583041);
#   way(id:479583043);
#   way(id:452279907); // Maclear's Beacon
#   way(id:291329699); // Maclear's Beacon
#   way(id:139746108); // Hoerikwaggo
#   way(id:33968433); // Hoerikwaggo
#   way(id:33969006); // Echo Valley
#   way(id:1151252211);
#   way(id:212070613); // Echo Valley
#   way(id:26356723); // Hut Access
#   way(id:39498521); // Hut Access
#   way(id:1355971604); // Woodhead Reservoir
#   way(id:26356778); // Woodhead Reservoir
#   way(id:71175494);
#   way(id:25906125);
#   way(id:73103836);
#   way(id:25906126);
#   way(id:73103849);
#   way(id:1355971605);
#   way(id:37355197);
#   way(id:37355196);
#   way(id:34000813);
#   way(id:751533121); // Waaikoppie
#   way(id:27609019); // Smuts' Track
#   way(id:26356491); // Smuts' Track
#   way(id:349881212); // Smuts' Track
#   way(id:479337102); // Smuts' Track
#   way(id:349881214);
#   way(id:484756095);
#   way(id:26358072);
#   way(id:349881216); // Hely Hutchinson Reservoir
#   way(id:341050624); // Hely Hutchinson Reservoir
#   way(id:1243718398); // Hely Hutchinson Reservoir
#   way(id:71175491); // Hely Hutchinson Reservoir
#   way(id:1151252212); // Hely Hutchinson Reservoir
#   way(id:71175493); // Junction Peak
#   way(id:212752984); // Junction Peak
#   way(id:212752983); // Junction Peak
# );
# out geom;

# %% [markdown]
# /* STJ query: */
#
# [out:json];
# (
#   way(id:70199485);  // Reef Bay
#   way(id:70200108); // Reef Bay
#   way(id:70265849); // Petroglyphs
#   way(id:70265857); // Reef Bay beach
#   way(id:70265854); // Reef Bay beach
#   way(id:70197894); // L'Esperance
#   way(id:70198038); // Lameshur Bay
#   way(id:152347757); // Reef Bay Great House
#   way(id:152347758); // Europa Bay
#   way(id:152347756); // Little Lameshur
#   way(id:70198197); // Lameshur Bay
#   way(id:70197991); // Lameshur Bay
#   way(id:70198283); // Lameshur Bay
#   way(id:70199286); // Yawzi Point
#   way(id:522502510); // Yawzi Point
#   way(id:376087841); // Yawzi Point
#   way(id:765276193); // Yawzi Point
#   way(id:70198606); // Bordeaux
#   way(id:70199164); // Bordeaux
#   way(id:70198591); // Great Lameshur
#   way(id:70198895); // Great Lameshur
#   way(id:70198855); // Great Lameshur
#   way(id:70200040); // Great Lameshur
#   way(id:1024625770); // Reef Bay Surfer's Scramble
#   way(id:70198503); // Saltpond
#   way(id:70197954); // Saltpond
#   way(id:70280377); // Saltpond
#   way(id:887601464); // Saltpond
#   way(id:836167664); // Saltpond
#   way(id:836167953); // Saltpond
#   way(id:70198003); // Drunk Bay
#   way(id:887601465); // Ram Head
#   way(id:70280365); // Ram Head
#   way(id:887601468); // Ram Head
#   way(id:458948476); // Haulover
#   way(id:70198947); // Brown Bay
#   way(id:70199834); // Johnny Horn
#   way(id:70199873); // Johnny Horn
#   way(id:70198087); // Johnny Horn
#   way(id:844870190); // Windy Hill
#   way(id:70255324); // Leinster
#   way(id:70255329); // Francis Bay
#   way(id:377531893); // Maria Hope
#   way(id:70280371); // Cinnamon Bay
#   way(id:458950168); // America House
#   way(id:1209163505); // Dennis Bay
#   way(id:70198180); // Peace Hill
#   way(id:70198716); // Caneel Hill
#   way(id:70198067); // Caneel Hill
#   way(id:152346540); // Margaret Hill
#   way(id:70198310); // Catchment
#   way(id:152988266); // Catchment
#   way(id:70265847); // Caneel Hill Spur
#   way(id:70199851); // Caneel Hill Spur
#   way(id:70198764); // Caneel Hill Spur
#   way(id:70265851); // Caneel Hill Spur
#   way(id:138445924); // Lind Point
#   way(id:1140674624); // Lind Point
#   way(id:70199604); // Upper Lind Point
#   way(id:70199948); // Upper Lind Point
# );
# out geom;

# %% [markdown]
# /* Mansfield query: */
#
# [out:json];
# (
#   way(id:48663853);  // Sunset Ridge
#   way(id:1109538831);  // Sunset Ridge spur
#   way(id:48665787);  // Halfway House
#   way(id:852712864);  // Long Trail
#   way(id:48663887);  // Laura Cowles
#   way(id:1109538830);  // Laura Cowles spur
#   way(id:48663852);  // Cantilever
#   way(id:185980437);  // Sterling Pond
#   way(id:391736);  // Long Trail near nose
#   way(id:458072757);  // Long Trail forehead
#   relation(id:6619374);  // CCC Road
#   way(id:48682938); // Nose
#   way(id:484296453);  // Eagle's Cut
#   way(id:484297468);  // low Maple Ridge
#   way(id:170293923);  // Maple Ridge
#   way(id:170293925);  // high Maple Ridge
#   way(id:484418748);  // Long Trail
#   way(id:484418753); // Long Trail
#   way(id:458237838);  // Long Trail
#   way(id:37861414);  // Long Trail
#   way(id:48665777);  // Lake Mansfield
#   way(id:484290442);  // Nebraska Notch
#   way(id:1021927415); // Nebraska Notch
#   way(id:1021927414); // Nebraska Notch
# );
# out geom;

# %% [markdown]
# /* sample STJ query: */
#
# [out:json];
# (
#   way["highway"~"path|footway"](around:1000,18.3356013499999,-64.7550406212072);  // Adjust radius and coordinates
#   relation["route"="hiking"](around:1000,18.3356013499999,-64.7550406212072);
# );
# out geom;

# %% [markdown]
# /* Vermonter Amtrak query - used a relation afterwards */
#
# [out:json];
# area["name"="Vermont"]->.searchArea;
# relation["operator"="Amtrak"](area.searchArea);
# (._;>;);
# out body;

# %% [markdown]
# /* Ollantaytambo railway */
#
# [out:json];
# node(around:10000, -13.2588, -72.2648)["railway"];
# way(around:10000, -13.2588, -72.2648)["railway"];
# (._;>;);
# out geom;
#
#
# [out:json];
# relation(id:8275132);
# out geom;

# %% [markdown]
# /* Puno - Cusco train */
#
# [out:json];
# relation(id:8266111);
# out geom;

# %% [markdown]
# /* london - bath train */
#
# [out:json];
# relation(id:9773637);
# out geom;
#
# /* london - inverness, through edinburgh */
# [out:json];
#   relation(id:6406403);
# out geom;
#
#
# /* edinburgh - north berwick */
# [out:json];
# relation(id:6399367);
# out geom;
#
# /* Mallaig ferry */
# [out:json];
# way(id:4904837);
# out geom;

# %% [markdown]
# /* STJ - Virgin Gorda */
# [out:json];
# way(id:835169173);
# out geom;
#
# /* STJ - Jost Van Dyke */
# [out:json];
# way(id:835088683);
# out geom;
#
# /* STJ - Red Hook */
# [out:json];
# way(id:38283719);
# out geom;
#
# /* Road Town - Anegada */
# [out:json];
# way(id:835105193);
# out geom;

# %% [markdown]
# /* ferry Drake - Sirena Corcovado */
# [out:json];
# (
#   way(id:254913398);
#   way(id:169826586);
#   way(id:83589227);
# );
# out geom;
#
# /* ferry Golfito - Puerto Jimenez */
# [out:json];
# way(id:101525175);
# out geom;
#
# /* Corcovado hike */
# [out:json];
# (
#     way(id:82531806);
#     way(id:1123502362);
#     way(id:1123502361);
#     way(id:1123502360);
#     way(id:1123502359);
#     way(id:1123502358);
#     way(id:162630052);
#     way(id:1123502357);
#     way(id:1123502356);
#     way(id:1123502355);
#     way(id:1123502354);
#     way(id:1123502351);
#     way(id:1123502352);
#     way(id:1123502353);
#     way(id:1123502350);
#     way(id:1123502349);
#     way(id:1123502363);
#     way(id:1123502364);
#     way(id:1123502365);
#     way(id:902479777);
# );
# out geom;

# %% [markdown]
# /* Amubri - Yorkin canoe */
# [out:json];
# (
#   way(id:383699517);
#   way(id:11801339);
# );
# out geom;

# %% [markdown]
# /* Chirripo hike */
# [out:json];
# (
#     way(id:1360690169);
#     way(id:1360690168);
#     way(id:1360690167);
#     way(id:1360690166);
#     way(id:143471132);
#     way(id:627460617);
# );
# out geom;

# %% [markdown]
# // Puntarenas ferry
# [out:json];
# (
#     way(id:61014461);
# );
# out geom;

# %% [markdown]
# // bocas del toro ferries
# [out:json];
# (
# way(30894242);
# way(30932835);
# way(331324656);
# way(1218559657);
# );
# out geom;
#
# // bastimentos hikes
# [out:json];
# (
# way(id:817738550);
# way(id:867128028);
# way(id:989183941);
# way(id:989174538);
# way(id:899641396);
# way(id:1350906383);
# way(id:899643564);
# way(id:868471634);
# way(id:868471635);
# way(id:868469186);
# way(id:331153477);
# way(id:607394252);
# way(id:676003363);
# way(id:821653503);
# way(id:331324662);
# way(id:331106782);
# );
# out geom;

# %% [markdown]
# // Pacuare river
# [out:json];
# (
#     way(id:907860639);
#     way(id:907860634);
#     way(id:907860635);
#     way(id:383911075);
# );
# out geom;

# %% [markdown]
# /* Cape Town to Robben Island */
# [out:json];
# way(id:88433954);
# out geom;

# %% [markdown]
# /* Istanbul ferry */
# [out:json];
# way(id:52089510);
# out geom;

# %% [markdown]
# /* Fort Cochin */
# [out:json];
# (
# way(id:1007981314);
# way(id:25978889);
# );
# out geom;

# %% [markdown]
# /* Kerala Backwaters */
# [out:json];
# (
# way(id:1100966866);
# way(id:123836588);
# way(id:777215878);
# way(id:253668199);
# way(id:1031072714);
# way(id:987875980);
# way(id:1096491416);
# way(id:777215877);
# way(id:1100966865);
# way(id:619731389);
# way(id:27837029);
# way(id:1100896882);
# way(id:856806123);
# way(id:330133093);
# way(id:987856387);
# way(id:987166967);
# way(id:986235075);
# way(id:985578130);
# way(id:958233200);
# way(id:1031072710);
# way(id:1280536040);
# way(id:884025529);
# way(id:203615187);
# way(id:400309887);
# way(id:1033126447);
# way(id:203630443);
# way(id:389837881);
# way(id:1031559246);
# way(id:787086054);
# way(id:787049920);
# way(id:474159245);
# way(id:987873454);
# way(id:987873715);
# way(id:987873716);
# way(id:330133086);
# way(id:985580474);
# way(id:27913361);
# way(id:987876286);
# );
# out geom;

# %% [markdown]
# // new delhi to mumbai
# [out:json];
# (
# relation(id:5423932);
# );
# out geom;
#
# // jaipur to sawai madhopur (on delhi-mumbai line)
# [out:json];
# (
# relation(id:9202265);
# );
# out geom;

# %% [markdown]
# // Amritsar - Ambala train
# [out:json];
# (
# relation(id:5561601);
# );
# out geom;
#
# // New Delhi - Ambala (Kolka) train
# [out:json];
# (
# relation(id:3434647);
# );
# out geom;

# %% [markdown]
# /* Jagdalpur to Viskhapatnam */
# [out:json];
# (
# relation(id:7474608);
# );
# out geom;
#
# // New Delhi to Raipur
# [out:json];
# (
# relation(id:18091482);
# );
# out geom;
#
# // Raipur to Jagdalpur
# [out:json];
# (
# // relation(id:18091482);
# //  relation(id:7474608);
#   relation(id:11233170);
#   relation(id:8414088);
#   way(id:1154136871);
#   way(id:590916283);
#   way(id:590916279);
#   way(id:119483483);
#   way(id:957248394);
#   way(id:957248392);
#   way(id:957239214);
#   way(id:724867973);
#   way(id:957239225);
#   way(id:957239222);
#   way(id:515833266);
#   way(id:1033721788);
#   way(id:1330211510);
#   way(id:1033721806);
#   way(id:244990747);
#   way(id:1339353902);
# );
# out geom;

# %% [markdown]
# /* Muyil Tulum Mayan canal float */
#
# [out:json];
# (
# way(id:220174032);
#   way(id:220174050);
# );
# out geom;
#
# /* Muyil "hike" */
#
# [out:json];
# (
# way(id:619865716);
#   way(id:1283381992);
#   way(id:762553245);
#   way(id:552813283);
#   way(id:561790099);
#   way(id:561790103);
#
# );
# out geom;

# %% [markdown]
# /* hiking Cabo Pulmo */
#
# [out:json];
# (
# way(id:179376818);
# way(id:179376819);
# way(id:139212872);
# way(id:222080664);
# way(id:179379689);
# way(id:139211395);
# way(id:139214382);
# way(id:139214387);
# way(id:139211635);
# );
# out geom;

# %% [markdown]
# // isla espiritu santo
# [out:json];
# (
#     way(id:154144540);
#     way(id:154141799);
#     way(id:154144539);
# );
# out geom;

# %% [markdown]
# /* Olympic Hot Springs Trail */
#
# [out:json];
# (
# way(id:313635256);
# way(id:780090607);
# way(id:779838499);
# way(id:779838500);
# way(id:313635255);
# way(id:1031861154);
# way(id:1031861153);
# way(id:139715541);
# way(id:1028195424);
# way(id:1028195425);
# way(id:1028195426);
# way(id:1028195427);
# way(id:36744475);
# way(id:41709592);
# way(id:1045973153);
# way(id:1031864033);
# way(id:1031864034);
# way(id:519351092);
# way(id:519351095);
# way(id:281059691);
# way(id:1028581106);
# way(id:1028581107);
# way(id:548271801);
# way(id:1028581103);
# way(id:1028581101);
# );
# out geom;
#
# [out:json];
# (
#   // Search for hiking routes near Olympic Hot Springs
#   relation["route"="hiking"](around:20000, 47.9725, -123.6350); // Olympic Hot Springs
#   // Search for paths and footways near Olympic Hot Springs
#   way["highway"="path"](around:20000, 47.9725, -123.6350); // Olympic Hot Springs
#   way["highway"="footway"](around:20000, 47.9725, -123.6350); // Olympic Hot Springs
# );
# (._;>;);
# out geom;

# %% [markdown]
# /* Netherlands rail */
# [out:json];
# (
# relation(id:192036);
# relation(id:7844176);
# relation(id:5290345);
#   );
# out geom;

# %% [markdown]
# // ferry Titicaca
# [out:json];
# (
#     way(id:474072603);
#     way(id:474072605);
# );
# out geom;
#
#
# // Sendero Pumamarca near Ollantaytambo
# [out:json];
# (
#   way["name"~"Sendero Ollanta-Pumamarca"](around:10000,-13.2588,-72.2648);
#   relation["name"~"Sendero Ollanta-Pumamarca"](around:10000,-13.2588,-72.2648);
# );
# out geom;
#
# // Huayna Picchu
# [out:json];
# (
# way(id:42871036);
# way(id:629542956);
# way(id:629542957);
# way(id:629542955);
# way(id:629494410);
# way(id:23785319);
# way(id:1267978717);
# way(id:1267978716);
# way(id:1267978715);
# way(id:1267978714);
# way(id:1267978713);
# way(id:1267978712);
# way(id:1267978711);
# way(id:1267978710);
# way(id:23785269);
# way(id:23785264);
#
# );
# out geom;

# %% [markdown]
# // Gunung Batur hike
# [out:json];
# (
# way(id:893158055);
# way(id:892526419);
# way(id:1234608279);
# way(id:187150483);
# way(id:619063379);
# way(id:223131326);
# way(id:223943133);
# way(id:619063389);
# );
# out geom;
#
# // Menjangan ferry
# [out:json];
# (
# way(id:200945726);
# );
# out geom;
#
# // Candi Dasa hike
# [out:json];
# (
# way(id:104800589);
# );
# out geom;

# %% [markdown]
# // Kalalau, Kauai
# [out:json];
# (
# relation(id:9146299);
# );
# out geom;
#
# // Pihea Trail
# [out:json];
# (
# way(id:48443877);
# way(id:657962965);
# way(id:657962956);
# way(id:657962962);
# way(id:534166783);
# );
# out geom;
#
# // Mahaulepu
# [out:json];
# (
# way(id:658354381);
# way(id:658354320);
# way(id:658354322);
# way(id:658354321);
# way(id:45809819);
# way(id:658354289);
# way(id:658354355);
# way(id:658354354);
# way(id:658354353);
# way(id:658354374);
# way(id:658354319);
# way(id:658354375);
# way(id:658354376);
# way(id:658354372);
# way(id:658354371);
# way(id:658354370);
# way(id:658354367);
# way(id:658354368);
# way(id:658354369);
# way(id:658354377);
# way(id:658354380);
# way(id:658354318);
# way(id:658354379);
# way(id:658354378);
# way(id:970984843);
# way(id:970984842);
# way(id:970984844);
# way(id:658354323);
# way(id:255863134);
# way(id:255863131);
# way(id:1090913860);
# way(id:144966704);
# );
# out geom;

# %% [markdown]
# // Ometepe hike
# [out:json];
# (
#     way(id:396320281);
# );
# out geom;
#
# // Manzanillo hike
# [out:json];
# (
# way(id:1021287514);
# way(id:37606675);
# way(id:265983424);
# way(id:1122307568);
# way(id:1122307569);
# way(id:1122528741);
# way(id:1344558715);
# way(id:1122307571);
# );
# out geom;
#
# // Volcan Tajumulco hike
# [out:json];
# (
#     way(id:126263507);
#     way(id:878651834);
#     way(id:1120225708);
#     way(id:1120225709);
#     way(id:1120225707);
#     way(id:878651835);
#     way(id:878651836);
#     way(id:1120225706);
#     way(id:878651837);
#     way(id:878658239);
#     way(id:1006229187);
#     way(id:1120225561);
#     way(id:1120225563);
#     way(id:1120225562);
#     way(id:878651838);
# );
# out geom;

# %% [markdown]
# // Mt Washington & Presidential Range
# [out:json];
# (
#     relation(id:3075304);
#     way(id:44896263);
#     way(id:44946661);
#     way(id:44899227);
#     relation(id:5810285);
#     way(id:118381941);
#     way(id:167141863);
#     way(id:55231081);
#     way(id:1211301578);
#     way(id:80794083);
#     way(id:1211303156);
#     way(id:1211303155);
#     way(id:546806005);
#     way(id:55231073);
#     way(id:44897794);
#     way(id:1262294795);
# );
# out geom;

# %% [markdown]
# // echo lake, catskills
# [out:json];
# (
# relation(id:6196954);
# way(id:863498517);
# way(id:1355283048);
# way(id:20199664);
# way(id:416490189);
# way(id:1354043238);
# way(id:1354043237);
# way(id:416490188);
# way(id:111804369);
# way(id:234370178);
# way(id:416490186);
# way(id:1292385127);
# );
# out geom;
#
# // blue hole, catskills
# [out:json];
# (
# way(id:780257981);
# way(id:231407450);
# way(id:780257979);
# way(id:780257978);
# way(id:415180367);
# way(id:780257980);
# way(id:231407449);
# );
# out geom;
